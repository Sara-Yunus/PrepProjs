# %%
from scipy.io import arff
import pandas as pd

# %%
data = arff.loadarff(r"E:\ZIP1--clustering-benchmark-master\clustering-benchmark-master\src\main\resources\datasets\real-world\dermatology.arff")

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#   erythema scaling definite_borders itching koebner_phenomenon  \
# 0     b'2'    b'2'             b'0'    b'3'               b'0'
# 1     b'3'    b'3'             b'3'    b'2'               b'1'
# 2     b'2'    b'1'             b'2'    b'3'               b'1'
# 3     b'2'    b'2'             b'2'    b'0'               b'0'
# 4     b'2'    b'3'             b'2'    b'2'               b'2'
#
#   polygonal_papules follicular_papules oral_mucosal_involvement  \
# 0              b'0'               b'0'                     b'0'
# 1              b'0'               b'0'                     b'0'
# 2              b'3'               b'0'                     b'3'
# 3              b'0'               b'0'                     b'0'
# 4              b'2'               b'0'                     b'2'
#
#   knee_and_elbow_involvement scalp_involvement  ...  \
# 0                       b'1'              b'0'  ...
# 1                       b'1'              b'1'  ...
# 2                       b'0'              b'0'  ...
# 3                       b'3'              b'2'  ...
# 4                       b'0'              b'0'  ...
#
#   disappearance_of_the_granular_layer vacuolisation_and_damage_of_basal_layer  \
# 0                                b'0'                                    b'0'
# 1                                b'0'                                    b'0'
# 2                                b'0'                                    b'2'
# 3                                b'3'                                    b'0'
# 4                                b'2'                                    b'3'
#
#   spongiosis saw-tooth_appearance_of_retes follicular_horn_plug  \
# 0       b'3'                          b'0'                 b'0'
# 1       b'0'                          b'0'                 b'0'
# 2       b'3'                          b'2'                 b'0'
# 3       b'0'                          b'0'                 b'0'
# 4       b'2'                          b'3'                 b'0'
#
#   perifollicular_parakeratosis inflammatory_monoluclear_inflitrate  \
# 0                         b'0'                                b'1'
# 1                         b'0'                                b'1'
# 2                         b'0'                                b'2'
# 3                         b'0'                                b'3'
# 4                         b'0'                                b'2'
#
#   band-like_infiltrate   Age class
# 0                 b'0'  55.0  b'2'
# 1                 b'0'   8.0  b'1'
# 2                 b'3'  26.0  b'3'
# 3                 b'0'  40.0  b'1'
# 4                 b'3'  45.0  b'3'
#
# [5 rows x 35 columns]

# %%
df.to_csv('dermatology.csv', index = False)

# %%
df1 = pd.read_csv('dermatology.csv')
df1
# Out:
#     erythema scaling definite_borders itching koebner_phenomenon  \
# 0       b'2'    b'2'             b'0'    b'3'               b'0'
# 1       b'3'    b'3'             b'3'    b'2'               b'1'
# 2       b'2'    b'1'             b'2'    b'3'               b'1'
# 3       b'2'    b'2'             b'2'    b'0'               b'0'
# 4       b'2'    b'3'             b'2'    b'2'               b'2'
# ..       ...     ...              ...     ...                ...
# 361     b'2'    b'1'             b'1'    b'0'               b'1'
# 362     b'3'    b'2'             b'1'    b'0'               b'1'
# 363     b'3'    b'2'             b'2'    b'2'               b'3'
# 364     b'2'    b'1'             b'3'    b'1'               b'2'
# 365     b'3'    b'2'             b'2'    b'0'               b'0'
#
#     polygonal_papules follicular_papules oral_mucosal_involvement  \
# 0                b'0'               b'0'                     b'0'
# 1                b'0'               b'0'                     b'0'
# 2                b'3'               b'0'                     b'3'
# 3                b'0'               b'0'                     b'0'
# 4                b'2'               b'0'                     b'2'
# ..                ...                ...                      ...
# 361              b'0'               b'0'                     b'0'
# 362              b'0'               b'0'                     b'0'
# 363              b'2'               b'0'                     b'2'
# 364              b'3'               b'0'                     b'2'
# 365              b'0'               b'0'                     b'0'
#
#     knee_and_elbow_involvement scalp_involvement  ...  \
# 0                         b'1'              b'0'  ...
# 1                         b'1'              b'1'  ...
# 2                         b'0'              b'0'  ...
# 3                         b'3'              b'2'  ...
# 4                         b'0'              b'0'  ...
# ..                         ...               ...  ...
# 361                       b'0'              b'0'  ...
# 362                       b'0'              b'0'  ...
# 363                       b'0'              b'0'  ...
# 364                       b'0'              b'0'  ...
# 365                       b'3'              b'3'  ...
#
#     disappearance_of_the_granular_layer  \
# 0                                  b'0'
# 1                                  b'0'
# 2                                  b'0'
# 3                                  b'3'
# 4                                  b'2'
# ..                                  ...
# 361                                b'0'
# 362                                b'1'
# 363                                b'0'
# 364                                b'0'
# 365                                b'2'
#
#     vacuolisation_and_damage_of_basal_layer spongiosis  \
# 0                                      b'0'       b'3'
# 1                                      b'0'       b'0'
# 2                                      b'2'       b'3'
# 3                                      b'0'       b'0'
# 4                                      b'3'       b'2'
# ..                                      ...        ...
# 361                                    b'0'       b'1'
# 362                                    b'0'       b'1'
# 363                                    b'3'       b'0'
# 364                                    b'2'       b'0'
# 365                                    b'0'       b'0'
#
#     saw-tooth_appearance_of_retes follicular_horn_plug  \
# 0                            b'0'                 b'0'
# 1                            b'0'                 b'0'
# 2                            b'2'                 b'0'
# 3                            b'0'                 b'0'
# 4                            b'3'                 b'0'
# ..                            ...                  ...
# 361                          b'0'                 b'0'
# 362                          b'0'                 b'0'
# 363                          b'3'                 b'0'
# 364                          b'1'                 b'0'
# 365                          b'0'                 b'0'
#
#     perifollicular_parakeratosis inflammatory_monoluclear_inflitrate  \
# 0                           b'0'                                b'1'
# 1                           b'0'                                b'1'
# 2                           b'0'                                b'2'
# 3                           b'0'                                b'3'
# 4                           b'0'                                b'2'
# ..                           ...                                 ...
# 361                         b'0'                                b'2'
# 362                         b'0'                                b'2'
# 363                         b'0'                                b'2'
# 364                         b'0'                                b'2'
# 365                         b'0'                                b'3'
#
#     band-like_infiltrate   Age class
# 0                   b'0'  55.0  b'2'
# 1                   b'0'   8.0  b'1'
# 2                   b'3'  26.0  b'3'
# 3                   b'0'  40.0  b'1'
# 4                   b'3'  45.0  b'3'
# ..                   ...   ...   ...
# 361                 b'0'  25.0  b'4'
# 362                 b'0'  36.0  b'4'
# 363                 b'3'  28.0  b'3'
# 364                 b'3'  50.0  b'3'
# 365                 b'0'  35.0  b'1'
#
# [366 rows x 35 columns]

# %%
lst= []

# %%
df1['erythema'] = df1['erythema'].apply(lambda x : x.split("'")[1])
df1
# Out:
#     erythema scaling definite_borders itching koebner_phenomenon  \
# 0          2    b'2'             b'0'    b'3'               b'0'
# 1          3    b'3'             b'3'    b'2'               b'1'
# 2          2    b'1'             b'2'    b'3'               b'1'
# 3          2    b'2'             b'2'    b'0'               b'0'
# 4          2    b'3'             b'2'    b'2'               b'2'
# ..       ...     ...              ...     ...                ...
# 361        2    b'1'             b'1'    b'0'               b'1'
# 362        3    b'2'             b'1'    b'0'               b'1'
# 363        3    b'2'             b'2'    b'2'               b'3'
# 364        2    b'1'             b'3'    b'1'               b'2'
# 365        3    b'2'             b'2'    b'0'               b'0'
#
#     polygonal_papules follicular_papules oral_mucosal_involvement  \
# 0                b'0'               b'0'                     b'0'
# 1                b'0'               b'0'                     b'0'
# 2                b'3'               b'0'                     b'3'
# 3                b'0'               b'0'                     b'0'
# 4                b'2'               b'0'                     b'2'
# ..                ...                ...                      ...
# 361              b'0'               b'0'                     b'0'
# 362              b'0'               b'0'                     b'0'
# 363              b'2'               b'0'                     b'2'
# 364              b'3'               b'0'                     b'2'
# 365              b'0'               b'0'                     b'0'
#
#     knee_and_elbow_involvement scalp_involvement  ...  \
# 0                         b'1'              b'0'  ...
# 1                         b'1'              b'1'  ...
# 2                         b'0'              b'0'  ...
# 3                         b'3'              b'2'  ...
# 4                         b'0'              b'0'  ...
# ..                         ...               ...  ...
# 361                       b'0'              b'0'  ...
# 362                       b'0'              b'0'  ...
# 363                       b'0'              b'0'  ...
# 364                       b'0'              b'0'  ...
# 365                       b'3'              b'3'  ...
#
#     disappearance_of_the_granular_layer  \
# 0                                  b'0'
# 1                                  b'0'
# 2                                  b'0'
# 3                                  b'3'
# 4                                  b'2'
# ..                                  ...
# 361                                b'0'
# 362                                b'1'
# 363                                b'0'
# 364                                b'0'
# 365                                b'2'
#
#     vacuolisation_and_damage_of_basal_layer spongiosis  \
# 0                                      b'0'       b'3'
# 1                                      b'0'       b'0'
# 2                                      b'2'       b'3'
# 3                                      b'0'       b'0'
# 4                                      b'3'       b'2'
# ..                                      ...        ...
# 361                                    b'0'       b'1'
# 362                                    b'0'       b'1'
# 363                                    b'3'       b'0'
# 364                                    b'2'       b'0'
# 365                                    b'0'       b'0'
#
#     saw-tooth_appearance_of_retes follicular_horn_plug  \
# 0                            b'0'                 b'0'
# 1                            b'0'                 b'0'
# 2                            b'2'                 b'0'
# 3                            b'0'                 b'0'
# 4                            b'3'                 b'0'
# ..                            ...                  ...
# 361                          b'0'                 b'0'
# 362                          b'0'                 b'0'
# 363                          b'3'                 b'0'
# 364                          b'1'                 b'0'
# 365                          b'0'                 b'0'
#
#     perifollicular_parakeratosis inflammatory_monoluclear_inflitrate  \
# 0                           b'0'                                b'1'
# 1                           b'0'                                b'1'
# 2                           b'0'                                b'2'
# 3                           b'0'                                b'3'
# 4                           b'0'                                b'2'
# ..                           ...                                 ...
# 361                         b'0'                                b'2'
# 362                         b'0'                                b'2'
# 363                         b'0'                                b'2'
# 364                         b'0'                                b'2'
# 365                         b'0'                                b'3'
#
#     band-like_infiltrate   Age class
# 0                   b'0'  55.0  b'2'
# 1                   b'0'   8.0  b'1'
# 2                   b'3'  26.0  b'3'
# 3                   b'0'  40.0  b'1'
# 4                   b'3'  45.0  b'3'
# ..                   ...   ...   ...
# 361                 b'0'  25.0  b'4'
# 362                 b'0'  36.0  b'4'
# 363                 b'3'  28.0  b'3'
# 364                 b'3'  50.0  b'3'
# 365                 b'0'  35.0  b'1'
#
# [366 rows x 35 columns]

# %%
df1['corrected_class'] = df1['class'].apply(lambda x : x.split("'")[1])
df1
# Out:
#     erythema scaling definite_borders itching koebner_phenomenon  \
# 0          2    b'2'             b'0'    b'3'               b'0'
# 1          3    b'3'             b'3'    b'2'               b'1'
# 2          2    b'1'             b'2'    b'3'               b'1'
# 3          2    b'2'             b'2'    b'0'               b'0'
# 4          2    b'3'             b'2'    b'2'               b'2'
# ..       ...     ...              ...     ...                ...
# 361        2    b'1'             b'1'    b'0'               b'1'
# 362        3    b'2'             b'1'    b'0'               b'1'
# 363        3    b'2'             b'2'    b'2'               b'3'
# 364        2    b'1'             b'3'    b'1'               b'2'
# 365        3    b'2'             b'2'    b'0'               b'0'
#
#     polygonal_papules follicular_papules oral_mucosal_involvement  \
# 0                b'0'               b'0'                     b'0'
# 1                b'0'               b'0'                     b'0'
# 2                b'3'               b'0'                     b'3'
# 3                b'0'               b'0'                     b'0'
# 4                b'2'               b'0'                     b'2'
# ..                ...                ...                      ...
# 361              b'0'               b'0'                     b'0'
# 362              b'0'               b'0'                     b'0'
# 363              b'2'               b'0'                     b'2'
# 364              b'3'               b'0'                     b'2'
# 365              b'0'               b'0'                     b'0'
#
#     knee_and_elbow_involvement scalp_involvement  ...  \
# 0                         b'1'              b'0'  ...
# 1                         b'1'              b'1'  ...
# 2                         b'0'              b'0'  ...
# 3                         b'3'              b'2'  ...
# 4                         b'0'              b'0'  ...
# ..                         ...               ...  ...
# 361                       b'0'              b'0'  ...
# 362                       b'0'              b'0'  ...
# 363                       b'0'              b'0'  ...
# 364                       b'0'              b'0'  ...
# 365                       b'3'              b'3'  ...
#
#     vacuolisation_and_damage_of_basal_layer spongiosis  \
# 0                                      b'0'       b'3'
# 1                                      b'0'       b'0'
# 2                                      b'2'       b'3'
# 3                                      b'0'       b'0'
# 4                                      b'3'       b'2'
# ..                                      ...        ...
# 361                                    b'0'       b'1'
# 362                                    b'0'       b'1'
# 363                                    b'3'       b'0'
# 364                                    b'2'       b'0'
# 365                                    b'0'       b'0'
#
#     saw-tooth_appearance_of_retes follicular_horn_plug  \
# 0                            b'0'                 b'0'
# 1                            b'0'                 b'0'
# 2                            b'2'                 b'0'
# 3                            b'0'                 b'0'
# 4                            b'3'                 b'0'
# ..                            ...                  ...
# 361                          b'0'                 b'0'
# 362                          b'0'                 b'0'
# 363                          b'3'                 b'0'
# 364                          b'1'                 b'0'
# 365                          b'0'                 b'0'
#
#     perifollicular_parakeratosis inflammatory_monoluclear_inflitrate  \
# 0                           b'0'                                b'1'
# 1                           b'0'                                b'1'
# 2                           b'0'                                b'2'
# 3                           b'0'                                b'3'
# 4                           b'0'                                b'2'
# ..                           ...                                 ...
# 361                         b'0'                                b'2'
# 362                         b'0'                                b'2'
# 363                         b'0'                                b'2'
# 364                         b'0'                                b'2'
# 365                         b'0'                                b'3'
#
#     band-like_infiltrate   Age class corrected_class
# 0                   b'0'  55.0  b'2'               2
# 1                   b'0'   8.0  b'1'               1
# 2                   b'3'  26.0  b'3'               3
# 3                   b'0'  40.0  b'1'               1
# 4                   b'3'  45.0  b'3'               3
# ..                   ...   ...   ...             ...
# 361                 b'0'  25.0  b'4'               4
# 362                 b'0'  36.0  b'4'               4
# 363                 b'3'  28.0  b'3'               3
# 364                 b'3'  50.0  b'3'               3
# 365                 b'0'  35.0  b'1'               1
#
# [366 rows x 36 columns]
