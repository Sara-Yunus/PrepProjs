# %%
from scipy.io import arff
import pandas as pd

# %%
data = arff.loadarff(r"E:\ZIP1--clustering-benchmark-master\clustering-benchmark-master\src\main\resources\datasets\real-world\dermatology.arff")

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#   erythema scaling definite_borders itching koebner_phenomenon  \
# 0     b'2'    b'2'             b'0'    b'3'               b'0'
# 1     b'3'    b'3'             b'3'    b'2'               b'1'
# 2     b'2'    b'1'             b'2'    b'3'               b'1'
# 3     b'2'    b'2'             b'2'    b'0'               b'0'
# 4     b'2'    b'3'             b'2'    b'2'               b'2'
#
#   polygonal_papules follicular_papules oral_mucosal_involvement  \
# 0              b'0'               b'0'                     b'0'
# 1              b'0'               b'0'                     b'0'
# 2              b'3'               b'0'                     b'3'
# 3              b'0'               b'0'                     b'0'
# 4              b'2'               b'0'                     b'2'
#
#   knee_and_elbow_involvement scalp_involvement  ...  \
# 0                       b'1'              b'0'  ...
# 1                       b'1'              b'1'  ...
# ...

# %%
df.to_csv('dermatology.csv', index = False)

# %%
df1 = pd.read_csv('dermatology.csv')
df1
# Out:
#     erythema scaling definite_borders itching koebner_phenomenon  \
# 0       b'2'    b'2'             b'0'    b'3'               b'0'
# 1       b'3'    b'3'             b'3'    b'2'               b'1'
# 2       b'2'    b'1'             b'2'    b'3'               b'1'
# 3       b'2'    b'2'             b'2'    b'0'               b'0'
# 4       b'2'    b'3'             b'2'    b'2'               b'2'
# ..       ...     ...              ...     ...                ...
# 361     b'2'    b'1'             b'1'    b'0'               b'1'
# 362     b'3'    b'2'             b'1'    b'0'               b'1'
# 363     b'3'    b'2'             b'2'    b'2'               b'3'
# 364     b'2'    b'1'             b'3'    b'1'               b'2'
# 365     b'3'    b'2'             b'2'    b'0'               b'0'
#
#     polygonal_papules follicular_papules oral_mucosal_involvement  \
# 0                b'0'               b'0'                     b'0'
# ...

# %%
df1.columns
# Out:
# Index(['erythema', 'scaling', 'definite_borders', 'itching',
#        'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
#        'oral_mucosal_involvement', 'knee_and_elbow_involvement',
#        'scalp_involvement', 'family_history', 'melanin_incontinence',
#        'eosinophils_in_the_infiltrate', 'PNL_infiltrate',
#        'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis',
#        'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges',
#        'elongation_of_the_rete_ridges',
#        'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule',
#        'munro_microabcess', 'focal_hypergranulosis',
#        'disappearance_of_the_granular_layer',
#        'vacuolisation_and_damage_of_basal_layer', 'spongiosis',
#        'saw-tooth_appearance_of_retes', 'follicular_horn_plug',
#        'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate',
#        'band-like_infiltrate', 'Age', 'class'],
#       dtype='object')

# %%
lt=['erythema', 'scaling','definite_borders', 'itching',
       'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
       'oral_mucosal_involvement', 'knee_and_elbow_involvement',
       'scalp_involvement', 'family_history', 'melanin_incontinence',
       'eosinophils_in_the_infiltrate', 'PNL_infiltrate',
       'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis',
       'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges',
       'elongation_of_the_rete_ridges',
       'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule',
       'munro_microabcess', 'focal_hypergranulosis',
       'disappearance_of_the_granular_layer',
       'vacuolisation_and_damage_of_basal_layer', 'spongiosis',
       'saw-tooth_appearance_of_retes', 'follicular_horn_plug',
       'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate',
       'band-like_infiltrate',]

# %%
df1['corrected_erythema'] = df1['erythema'].apply(lambda x : x.split("'")[1])
df1['corrected_scaling'] = df1['scaling'].apply(lambda x : x.split("'")[1])
df1['corrected_definite_borders'] = df1['definite_borders'].apply(lambda x : x.split("'")[1])
df1['corrected_itching'] = df1['itching'].apply(lambda x : x.split("'")[1])
df1['corrected_koebner_phenomenon'] = df1['koebner_phenomenon'].apply(lambda x : x.split("'")[1])
df1['corrected_polygonal_papules'] = df1['polygonal_papules'].apply(lambda x : x.split("'")[1])
df1['corrected_follicular_papules'] = df1['follicular_papules'].apply(lambda x : x.split("'")[1])
df1['corrected_oral_mucosal_involvement'] = df1['oral_mucosal_involvement'].apply(lambda x : x.split("'")[1])
df1['corrected_knee_and_elbow_involvement'] = df1['knee_and_elbow_involvement'].apply(lambda x : x.split("'")[1])
df1['corrected_scalp_involvement'] = df1['scalp_involvement'].apply(lambda x : x.split("'")[1])
df1['corrected_family_history'] = df1['family_history'].apply(lambda x : x.split("'")[1])
df1['corrected_melanin_incontinence'] = df1['melanin_incontinence'].apply(lambda x : x.split("'")[1])
df1['corrected_eosinophils_in_the_infiltrate'] = df1['eosinophils_in_the_infiltrate'].apply(lambda x : x.split("'")[1])
df1['corrected_PNL_infiltrate'] = df1['PNL_infiltrate'].apply(lambda x : x.split("'")[1])
df1['corrected_fibrosis_of_the_papillary_dermis'] = df1['fibrosis_of_the_papillary_dermis'].apply(lambda x : x.split("'")[1])
df1['corrected_exocytosis'] = df1['exocytosis'].apply(lambda x : x.split("'")[1])
df1['corrected_acanthosis'] = df1['acanthosis'].apply(lambda x : x.split("'")[1])
df1['corrected_hyperkeratosis'] = df1['hyperkeratosis'].apply(lambda x : x.split("'")[1])
df1['corrected_parakeratosis'] = df1['parakeratosis'].apply(lambda x : x.split("'")[1])
df1['corrected_clubbing_of_the_rete_ridges'] = df1['clubbing_of_the_rete_ridges'].apply(lambda x : x.split("'")[1])
df1['corrected_elongation_of_the_rete_ridges'] = df1['elongation_of_the_rete_ridges'].apply(lambda x : x.split("'")[1])
df1['corrected_thinning_of_the_suprapapillary_epidermis'] = df1['thinning_of_the_suprapapillary_epidermis'].apply(lambda x : x.split("'")[1])
df1['corrected_spongiform_pustule'] = df1['spongiform_pustule'].apply(lambda x : x.split("'")[1])
df1['corrected_munro_microabcess'] = df1['munro_microabcess'].apply(lambda x : x.split("'")[1])
df1['corrected_focal_hypergranulosis'] = df1['focal_hypergranulosis'].apply(lambda x : x.split("'")[1])
df1['corrected_disappearance_of_the_granular_layer'] = df1['disappearance_of_the_granular_layer'].apply(lambda x : x.split("'")[1])
df1['corrected_vacuolisation_and_damage_of_basal_layer'] = df1['vacuolisation_and_damage_of_basal_layer'].apply(lambda x : x.split("'")[1])
df1['corrected_spongiosis'] = df1['spongiosis'].apply(lambda x : x.split("'")[1])
df1['corrected_saw-tooth_appearance_of_retes'] = df1['saw-tooth_appearance_of_retes'].apply(lambda x : x.split("'")[1])
df1['corrected_follicular_horn_plug'] = df1['follicular_horn_plug'].apply(lambda x : x.split("'")[1])
df1['corrected_perifollicular_parakeratosis'] = df1['perifollicular_parakeratosis'].apply(lambda x : x.split("'")[1])
df1['corrected_inflammatory_monoluclear_inflitrate'] = df1['inflammatory_monoluclear_inflitrate'].apply(lambda x : x.split("'")[1])
df1['corrected_band-like_infiltrate'] = df1['band-like_infiltrate'].apply(lambda x : x.split("'")[1])
df1['corrected_class'] = df1['class'].apply(lambda x : x.split("'")[1])

df1
# Out:
#     erythema scaling definite_borders itching koebner_phenomenon  \
# 0       b'2'    b'2'             b'0'    b'3'               b'0'
# 1       b'3'    b'3'             b'3'    b'2'               b'1'
# 2       b'2'    b'1'             b'2'    b'3'               b'1'
# 3       b'2'    b'2'             b'2'    b'0'               b'0'
# 4       b'2'    b'3'             b'2'    b'2'               b'2'
# ..       ...     ...              ...     ...                ...
# 361     b'2'    b'1'             b'1'    b'0'               b'1'
# 362     b'3'    b'2'             b'1'    b'0'               b'1'
# 363     b'3'    b'2'             b'2'    b'2'               b'3'
# 364     b'2'    b'1'             b'3'    b'1'               b'2'
# 365     b'3'    b'2'             b'2'    b'0'               b'0'
#
#     polygonal_papules follicular_papules oral_mucosal_involvement  \
# 0                b'0'               b'0'                     b'0'
# ...

# %%
df1.columns
# Out:
# Index(['erythema', 'scaling', 'definite_borders', 'itching',
#        'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
#        'oral_mucosal_involvement', 'knee_and_elbow_involvement',
#        'scalp_involvement', 'family_history', 'melanin_incontinence',
#        'eosinophils_in_the_infiltrate', 'PNL_infiltrate',
#        'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis',
#        'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges',
#        'elongation_of_the_rete_ridges',
#        'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule',
#        'munro_microabcess', 'focal_hypergranulosis',
#        'disappearance_of_the_granular_layer',
#        'vacuolisation_and_damage_of_basal_layer', 'spongiosis',
#        'saw-tooth_appearance_of_retes', 'follicular_horn_plug',
#        'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate',
#        'band-like_infiltrate', 'Age', 'class', 'corrected_erythema',
# ...

# %%
df2 = df1.drop(lt, axis = 'columns')
df2
# Out:
#       Age class corrected_erythema corrected_scaling  \
# 0    55.0  b'2'                  2                 2
# 1     8.0  b'1'                  3                 3
# 2    26.0  b'3'                  2                 1
# 3    40.0  b'1'                  2                 2
# 4    45.0  b'3'                  2                 3
# ..    ...   ...                ...               ...
# 361  25.0  b'4'                  2                 1
# 362  36.0  b'4'                  3                 2
# 363  28.0  b'3'                  3                 2
# 364  50.0  b'3'                  2                 1
# 365  35.0  b'1'                  3                 2
#
#     corrected_definite_borders corrected_itching corrected_koebner_phenomenon  \
# 0                            0                 3                            0
# 1                            3                 2                            1
# 2                            2                 3                            1
# ...

# %%
derma = df2.drop(['class'], axis ='columns')
derma.to_csv('derma.csv', index = False)

# %%
input_set = df2.drop(['class','corrected_class'], axis ='columns')
input_set
# Out:
#       Age corrected_erythema corrected_scaling corrected_definite_borders  \
# 0    55.0                  2                 2                          0
# 1     8.0                  3                 3                          3
# 2    26.0                  2                 1                          2
# 3    40.0                  2                 2                          2
# 4    45.0                  2                 3                          2
# ..    ...                ...               ...                        ...
# 361  25.0                  2                 1                          1
# 362  36.0                  3                 2                          1
# 363  28.0                  3                 2                          2
# 364  50.0                  2                 1                          3
# 365  35.0                  3                 2                          2
#
#     corrected_itching corrected_koebner_phenomenon  \
# ...

# %%
input_set.isna().any()
# Out:
# Age                                                    True
# corrected_erythema                                    False
# corrected_scaling                                     False
# corrected_definite_borders                            False
# corrected_itching                                     False
# corrected_koebner_phenomenon                          False
# corrected_polygonal_papules                           False
# corrected_follicular_papules                          False
# corrected_oral_mucosal_involvement                    False
# corrected_knee_and_elbow_involvement                  False
# corrected_scalp_involvement                           False
# corrected_family_history                              False
# corrected_melanin_incontinence                        False
# corrected_eosinophils_in_the_infiltrate               False
# corrected_PNL_infiltrate                              False
# corrected_fibrosis_of_the_papillary_dermis            False
# ...

# %%
input_set['Age'] = input_set['Age'].fillna(input_set['Age'].mean())
input_set
# Out:
#       Age corrected_erythema corrected_scaling corrected_definite_borders  \
# 0    55.0                  2                 2                          0
# 1     8.0                  3                 3                          3
# 2    26.0                  2                 1                          2
# 3    40.0                  2                 2                          2
# 4    45.0                  2                 3                          2
# ..    ...                ...               ...                        ...
# 361  25.0                  2                 1                          1
# 362  36.0                  3                 2                          1
# 363  28.0                  3                 2                          2
# 364  50.0                  2                 1                          3
# 365  35.0                  3                 2                          2
#
#     corrected_itching corrected_koebner_phenomenon  \
# ...

# %%
input_set.isna().any()
# Out:
# Age                                                   False
# corrected_erythema                                    False
# corrected_scaling                                     False
# corrected_definite_borders                            False
# corrected_itching                                     False
# corrected_koebner_phenomenon                          False
# corrected_polygonal_papules                           False
# corrected_follicular_papules                          False
# corrected_oral_mucosal_involvement                    False
# corrected_knee_and_elbow_involvement                  False
# corrected_scalp_involvement                           False
# corrected_family_history                              False
# corrected_melanin_incontinence                        False
# corrected_eosinophils_in_the_infiltrate               False
# corrected_PNL_infiltrate                              False
# corrected_fibrosis_of_the_papillary_dermis            False
# ...

# %%
target_set = df1['corrected_class']
target_set
# Out:
# 0      2
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 361    4
# 362    4
# 363    3
# 364    3
# 365    1
# Name: corrected_class, Length: 366, dtype: object

# %%
from sklearn.model_selection import train_test_split
X,x,Y,y = train_test_split(input_set, target_set, test_size=0.25)

# %%
X                 # Age column is now the first column of the dataframe.
# Out:
#       Age corrected_erythema corrected_scaling corrected_definite_borders  \
# 292  27.0                  2                 3                          2
# 26   10.0                  1                 1                          0
# 209  27.0                  2                 3                          2
# 246  55.0                  2                 2                          2
# 216  50.0                  2                 2                          3
# ..    ...                ...               ...                        ...
# 290  27.0                  2                 2                          3
# 124  29.0                  3                 2                          2
# 191  38.0                  2                 3                          3
# 72   52.0                  1                 1                          1
# 339  51.0                  2                 1                          2
#
#     corrected_itching corrected_koebner_phenomenon  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression( max_iter=1500, random_state=10)
model.fit(X,Y)
# Out:
# LogisticRegression(max_iter=1500, random_state=10)

# %%
model.score(x,y)
# Out:
# 0.9565217391304348

# %% [markdown]
# # Using Cross-validation

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
lr = cross_val_score(LogisticRegression(max_iter=1100), input_set,target_set)
lr
# Out:
# array([0.98648649, 0.97260274, 0.95890411, 0.98630137, 0.93150685])

# %%
dt = cross_val_score(DecisionTreeClassifier(), input_set,target_set )
dt
# Out:
# array([0.89189189, 0.95890411, 0.87671233, 0.93150685, 0.95890411])

# %%
sv = cross_val_score(SVC(), input_set,target_set )
sv
# Out:
# array([0.66216216, 0.69863014, 0.75342466, 0.7260274 , 0.68493151])

# %%
rf = cross_val_score(RandomForestClassifier(n_estimators=40), input_set,target_set)
rf
# Out:
# array([0.98648649, 1.        , 0.97260274, 0.98630137, 0.91780822])

# %%
np.average(lr)
# Out:
# 0.9671603109959275

# %%
np.average(dt)
# Out:
# 0.9235838578304332

# %%
np.average(sv)
# Out:
# 0.7050351721584599

# %%
np.average(rf)
# Out:
# 0.9726397630507219

# %% [markdown]
# # Best score is from Random Forest Classifier which is 97.26% so far.

# %% [markdown]
#  Using GridSearchCV without Pipeline

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ShuffleSplit

# %%
def best_model_using_gridsearchCV(X,Y):
    algos={
        'linear regression' : {
            'model': LogisticRegression(max_iter=2500),
            'parameters' : {
                'fit_intercept' : [True, False],
                'random_state': [1,10,30,50,100],
                'solver': ['liblinear', 'saga','sag']
            }
        },
#         'decision tree': {
#             'model' : DecisionTreeClassifier(),
#             'parameters' :{
#                 'random_state': [1,5,10,30,50,100],
#                 'criterion': ['gini', 'entropy'],
#                 'splitter':['best', 'random'],
#                 'min_samples_split': [10,50,100]
#             }
#         },
#         'svc' : {
#             'model': SVC(),
#             'parameters': {
#                 'C': [10, 20, 50 ,100, 150],
#                 'kernel' : ['rbf','linear']
#             }
#         },
        'random forest' :{
            'model': RandomForestClassifier(),
            'parameters' :{
                'random_state': [5,10],
                'criterion' : [ 'gini', 'entropy'],
                'n_estimators': [1,5,10],

            }
        }
    }
    
    scores = []
    best_estimators = {}
    cv = ShuffleSplit(n_splits=10, test_size=0.25)
    
    for algos_name, config in algos.items():
        gs = GridSearchCV(config['model'], config['parameters'], cv=cv, return_train_score = False)
        gs.fit(X,Y)
        scores.append({
            'model' : algos_name,
            'best_score': gs.best_score_ ,
            'best_parameter': gs.best_params_
        })
        best_estimators[algos_name] = gs.best_estimator_
#     print(best_estimators)
    return pd.DataFrame(scores, columns= ['model', 'best_score', 'best_parameter'])

# %%
best_model_using_gridsearchCV(input_set, target_set)
# Out:
#                model  best_score  \
# 0  linear regression    0.973913
# 1      random forest    0.965217
#
#                                       best_parameter
# 0  {'fit_intercept': True, 'random_state': 1, 'so...
# 1  {'criterion': 'gini', 'n_estimators': 10, 'ran...

# %%
best_estimators
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 best_estimators
#
# NameError: name 'best_estimators' is not defined

# %%
best_clf = best_estimators['random forest']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 best_clf = best_estimators['random forest']
#
# NameError: name 'best_estimators' is not defined

# %% [markdown]
# Saving the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
