# %%
from scipy.io import arff
import pandas as pd

# %%
data = arff.loadarff(r"E:\ZIP1--clustering-benchmark-master\clustering-benchmark-master\src\main\resources\datasets\real-world\letter.arff")

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#    x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  xybar  x2ybr  \
# 0    2.0    4.0    4.0   3.0    2.0    7.0    8.0    2.0    9.0   11.0    7.0
# 1    4.0    7.0    5.0   5.0    5.0    5.0    9.0    6.0    4.0    8.0    7.0
# 2    7.0   10.0    8.0   7.0    4.0    8.0    8.0    5.0   10.0   11.0    2.0
# 3    4.0    9.0    5.0   7.0    4.0    7.0    7.0   13.0    1.0    7.0    6.0
# 4    6.0    7.0    8.0   5.0    4.0    7.0    6.0    3.0    7.0   10.0    7.0
#
#    xy2br  x-ege  xegvy  y-ege  yegvx class
# 0    7.0    1.0    8.0    5.0    6.0  b'Z'
# 1    9.0    2.0    9.0    7.0   10.0  b'P'
# 2    8.0    2.0    5.0    5.0   10.0  b'S'
# 3    8.0    3.0    8.0    0.0    8.0  b'H'
# 4    9.0    3.0    8.0    3.0    7.0  b'H'

# %%
df.shape
# Out:
# (20000, 17)

# %%
type((df['class']=="b'Z'").values)
# Out:
# numpy.ndarray

# %%
df.to_csv('letter.csv', index = False)

# %%
df1 = pd.read_csv('letter.csv')
df1
# Out:
#        x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  xybar  \
# 0        2.0    4.0    4.0   3.0    2.0    7.0    8.0    2.0    9.0   11.0
# 1        4.0    7.0    5.0   5.0    5.0    5.0    9.0    6.0    4.0    8.0
# 2        7.0   10.0    8.0   7.0    4.0    8.0    8.0    5.0   10.0   11.0
# 3        4.0    9.0    5.0   7.0    4.0    7.0    7.0   13.0    1.0    7.0
# 4        6.0    7.0    8.0   5.0    4.0    7.0    6.0    3.0    7.0   10.0
# ...      ...    ...    ...   ...    ...    ...    ...    ...    ...    ...
# 19995    5.0   10.0    5.0   8.0    3.0    4.0   10.0    7.0    8.0   12.0
# 19996    4.0    7.0    6.0   5.0    3.0    7.0    8.0    2.0   10.0   12.0
# 19997    4.0    8.0    4.0   6.0    4.0    7.0    8.0    7.0    4.0   10.0
# 19998    4.0   11.0    4.0   8.0    3.0    0.0    2.0    4.0    6.0    1.0
# 19999    5.0    9.0    6.0  11.0    6.0    8.0    7.0    6.0    3.0    8.0
#
#        x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx class
# ...

# %%
df1['corrected_class'] = df1['class'].apply(lambda x : x.split("'")[1])
df1
# Out:
#        x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  xybar  \
# 0        2.0    4.0    4.0   3.0    2.0    7.0    8.0    2.0    9.0   11.0
# 1        4.0    7.0    5.0   5.0    5.0    5.0    9.0    6.0    4.0    8.0
# 2        7.0   10.0    8.0   7.0    4.0    8.0    8.0    5.0   10.0   11.0
# 3        4.0    9.0    5.0   7.0    4.0    7.0    7.0   13.0    1.0    7.0
# 4        6.0    7.0    8.0   5.0    4.0    7.0    6.0    3.0    7.0   10.0
# ...      ...    ...    ...   ...    ...    ...    ...    ...    ...    ...
# 19995    5.0   10.0    5.0   8.0    3.0    4.0   10.0    7.0    8.0   12.0
# 19996    4.0    7.0    6.0   5.0    3.0    7.0    8.0    2.0   10.0   12.0
# 19997    4.0    8.0    4.0   6.0    4.0    7.0    8.0    7.0    4.0   10.0
# 19998    4.0   11.0    4.0   8.0    3.0    0.0    2.0    4.0    6.0    1.0
# 19999    5.0    9.0    6.0  11.0    6.0    8.0    7.0    6.0    3.0    8.0
#
# ...

# %%
input_set = df1.drop(['class', 'corrected_class'], axis = 'columns')
# input_set

# %%
target_set = df1['corrected_class']
# target_set

# %%
(df1['corrected_class'].loc[4])
# Out:
# 'H'

# %%
type(df1['corrected_class'].values)
# Out:
# numpy.ndarray

# %%
type(df1['corrected_class'].loc[4])
# Out:
# str

# %%
from sklearn.model_selection import train_test_split

# %%
X,x,Y,y = train_test_split(input_set, target_set, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=1000, solver = 'liblinear')

# %%
model.fit(X,Y)
# Out:
# LogisticRegression(max_iter=1000, solver='liblinear')

# %%
model.score(x,y)
# Out:
# 0.7295

# %% [markdown]
# Using GridSearchCV

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
# from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import classification_report

# %%
model_params = {
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(max_iter = 1000,solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}

for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X, Y)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df2 = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df2
# Out:
#                  model  best_score  \
# 0        random_forest    0.924813
# 1  logistic_regression    0.721625
#
#                                     best_params
# 0  {'randomforestclassifier__n_estimators': 10}
# 1                 {'logisticregression__C': 10}

# %% [markdown]
# Reason for such a delay in this pipeline's execution is 20000 rows of data, this huge!
# Probably cross validation and GridSearchCV w/o pipeline will give faster results.

# %%
best_estimators
# Out:
# {'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=10, max_iter=1000, solver='liblinear'))])}
